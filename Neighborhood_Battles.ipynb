# %% [markdown]
# <a href="https://colab.research.google.com/github/vonnan/IBM-capstone-project/blob/main/Neighborhood_Battles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Neighborhood Battles (part I)
#
# ### Introduction and Background
#
# A friend wants to start her own dimsum restaurant in one of neighborhood in Edison. She hired me as her data scientist to help her decide which neighborhood/location she should open the business.
#
# Based on my research,  Edison is the fifth-most populous municipality in New Jersey, with population a little more than 100K, 29.27% Asian are residing in Edison township.  It has many Asian supermarkets that Asian residents go to every week. There are about at least 25 (popular) Chinese restaurants in town, only one is dimsum place.
#
# Edison is a huge town with a total area of 30.69 square miles (79.49 km2) and 31 nsections/neighborhoods. We want to select the most popular place for restaurant business.
#
# ### Data used in this report
#
# 1. Dataframe: Edison ----Web Scraping Edison neighborhood data with neighborhood name, latitude/longitude
# (Need some data cleaning for the data)
#
# 2. Dataframe: Edison (with Geo Label added)----Using unsupervised KMeans clustering and lat/lon only, divide Edison into 4 big clusters (geogrphically divided), adding Geo Labels
#
# 3. Dataframe: Edison_venues----Make calls to the Foursquare API for exploring each neighborhood, finding the top 100 venues within 1000 meter radius of each neighborhood.
#
# 4. Dataframe: Edison_onehot---Using pd.get_dummies to change the venue categories into numerical values
#
# 5. Dataframe: Edison_grouped---Using groupby to find for each neighborhood the mean value for each categories, the data frame is Edison
#
# 6. Dataframe: Edison_top_venues----In the mean time, by sort_values, find the top 10 popular venues for each neighborhood.
#
# 7. Dataframe: Edison_merge---- Edison_top_venues added with Venue Label, then merged into dataframe of Edison on "Neighborhood" ---Using unsuperized KMeans clustering on dataframe of Edison_grouped to get the clustering based on venues. The Venue Label is added based on the clustering result into Edison_top_venues and then it is merged with dataframe of Edison on "Neighborhood".
#
# 8. Dataframe: Edison_Chinatown: We found one of the cluster based on "Venue Label" has specialty on Asian restaurants (Chinese, Indian, Korean, Malay, Mongolia, Japanese etc), Asian supermarkets, Asian dessert shop(Bakery/Bubble Tea/Frozen Yogurt etc). The cluster includes 9 neighborhoods. We will focus on this dataframe for the part 2 analysis.
#
# ### Preliminary Data Visualizetion
#
# I did preliminary visualization on the data (part 2 will have much more)
#
# 1. Edison_map: Use folium.map to draw Edison on the map
#
# 2. Edison_map (neighborhoods added with different colors based on Geo Label) Use folium.CircleMarker for all the neighborhoods in Edison,  use different colors for different neighborhood clusters based on Geo Label
#
# 3.  Edison_map (neighborhoods added with different colors based on Venue Label) Use folium.CircleMarker for all the neighborhoods, based on Venue Label
#
# 4. Edison_Chinatown_map: focused on the venue cluster 0, which I called it Edison Chinatown.
#
# 5. Edison_Chinatown_map (Added Asian restaurants, Asian dessert shop and Asian supermarket

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML

# %% [markdown]
# ###Dataframe: Edison ----Web Scraping Edison neighborhood data with neighborhood name, latitude/longitude (Need some data cleaning for the data)

# %%
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_neighborhoods_in_Edison,_New_Jersey")
cols = ["Name", "Coordinate", "Notes"]
Edison = df[0][cols].copy()
Edison.head()
Edison.iloc[18]["Coordinate"] = "40°31′24″N 74°21′28″W\ufeff / \ufeff40.522964°N 74.411674°W"
def getLatLon(df):
  lat = []
  lng = []
  for i in range(len(df)):
    row = df.loc[i]  
    latlon =row["Coordinate"][:-2].split("/ \ufeff")[-1].split("°N ")
    lat.append(latlon[0])
    lng.append(latlon[1])
  return lat, lng
lat,lng = getLatLon(Edison)
Edison["Latitude"], Edison["Longitude"] = getLatLon(Edison)
Edison.drop(columns = "Coordinate", inplace = True)
Edison["Latitude"] = Edison["Latitude"].astype("float")
Edison["Longitude"] = ("-"+Edison["Longitude"]).astype("float")
Edison.rename(columns= {"Name" : "Neighborhood"}, inplace = True)
Edison
# Out:
#                 Neighborhood  \
# 0                 Bonhamtown
# 1           Camp Kilmer site
# 2               Clara Barton
# 3                  Greensand
# 4                Haven Homes
# 5                    Lahiere
# 6               Lincoln Park
# 7                   Lindenau
# 8            Martins Landing
# 9                 Menlo Park
# 10           Menlo Park Mall
# 11                 Metropark
# 12  Middlesex County College
# 13                 New Dover
# 14                New Durham
# 15                     Nixon
# 16              North Edison
# 17                  Oak Tree
# 18             Oak Tree Road
# 19                   Phoenix
# 20                Piscataway
# 21                   Potters
# 22                  Pumptown
# 23            Raritan Center
# 24             Raritan Manor
# 25                Sand Hills
# 26               Silver Lake
# 27                   Stelton
# 28                 Valentine
# 29          Vineyard Village
# 30           Washington Park
#
#                                                 Notes   Latitude  Longitude
# 0   The neighborhood began as colonial village tha...  40.523330 -74.357780
# 1   Abutting the Livingston Campus (Rutgers Univer...  40.520830 -74.413060
# 2   Named for Clara Barton. Located in the eastern...  40.534170 -74.339440
# 3   Site of the Kin-Buc Landfill, where Edmonds Cr...  40.491670 -74.387220
# 4                                                 NaN  40.509440 -74.406390
# 5   Lahiere is a neighbohood in the Stelton sectio...  40.518890 -74.402500
# 6   For other places named Lincoln Park, New Jerse...  40.518890 -74.402500
# 7   Lindenauis a neighborhood of the Stelton secti...  40.515000 -74.411110
# 8   Located on the northern banks of the Raritan R...  40.493060 -74.399720
# 9   Menlo Park is where, in 1876, Thomas Edison se...  40.565000 -74.337500
# 10  Super regional shopping mall on U.S. Route 1 a...  40.538330 -74.378610
# 11  Largely located in neighboring Iselin, the off...  40.568080 -74.329795
# 12  Sited 159 acres (64 ha) of the former Raritan ...  40.505830 -74.366110
# 13  The neighborhood began as colonial village tha...  40.585000 -74.343330
# 14                                                NaN  40.543610 -74.406110
# 15                                                NaN  40.514170 -74.367500
# 16                                                NaN  40.600000 -74.377500
# 17  An area of the battlefield of the Oak Tree Eng...  40.577780 -74.376670
# 18  Shopping strip runs through Edison and neighbo...  40.522964 -74.411674
# 19  Located in the eastern part of the township, P...  40.529720 -74.341110
# 20  This is the oldest neighborhood in Edison. Alo...  40.501670 -74.395830
# 21  In the northern part of the township Potters w...  40.593610 -74.361390
# 22  Pumptown is a residential neighborhood with a ...  40.563060 -74.373330
# 23  Sited on part if the former Raritan Arsenal,[4...  40.522500 -74.337780
# 24                                                NaN  40.536390 -74.336670
# 25  Sand Hills is a neighborhood straddling Edison...  40.525000 -74.319440
# 26  A small lake of same name borders the neighbor...  40.496209 -74.402813
# 27                    One the oldest parts of Edison.  40.514170 -74.403610
# 28  Valentine is adjacent to the Fords section of ...  40.530830 -74.325560
# 29  Adjacent to former Edison Assembly. Edward Ant...  40.524728 -74.375613
# 30         Washington Park is to the east of Stelton.  40.513890 -74.398330

# %% [markdown]
# ###Edison_Map

# %%
address = "Edison, NJ"
location = Nominatim(user_agent= "edison_explorer").geocode(address)
lat = location.latitude
lng = location.longitude
Edison_map = folium.Map([lat, lng], zoom_start= 12.5)

# %% [markdown]
# ### Use Geolocation to divide the neighborhoods in Edison (KMeans Clustering)

# %%
X = Edison[["Latitude", "Longitude"]]
KM = KMeans(n_clusters= 4, n_init = 12, random_state= 0)
KM.fit(X)
Edison["Geo Label"] = KM.labels_
colors = ["red", "blue", "green", "purple"]
for name, lat, lng, geo_label in zip(Edison["Neighborhood"], Edison["Latitude"], Edison["Longitude"], Edison["Geo Label"]):
  label = name
  color = colors[geo_label]
  folium.CircleMarker(
      [lat, lng],
      radius = 10,
      fill = True,
      popup = label,
      color = color,
      fill_color = color,
      fill_opacity = 0.3
  ).add_to(Edison_map)

#Edison.rename(columns= {"Name" : "Neighborhood"}, inplace = True)

# %%
Edison_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###Get the venues for the neighborhood, radius = 1000 and limit = 100
#
# ### We are going to collect all the venues from the FourSquare
#
# url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format( CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)

# %%
CLIENT_ID = 'KWTBOAQUOFKZSP5QHAZ530MZ5WKAUPBPCFZKQJNVEM5EJV1R' # your Foursquare ID
CLIENT_SECRET = 'LP251NSOTLWM5PWMYKWNCRMMFSSRRZC5D4PHSGLASZ1GXK5T' # your Foursquare Secret
ACCESS_TOKEN = '2NX33SVZLUCMUQOF01CKEZ2PHKA3VAR4NPDCGD4DWOMNVTHP' # your FourSquare Access Token
VERSION = '20201205'
LIMIT = 100
radius = 1000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET: ' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KWTBOAQUOFKZSP5QHAZ530MZ5WKAUPBPCFZKQJNVEM5EJV1R
# CLIENT_SECRET: LP251NSOTLWM5PWMYKWNCRMMFSSRRZC5D4PHSGLASZ1GXK5T

# %% [markdown]
# ###Dataframe: Edison_venues----Make calls to the Foursquare API for exploring each neighborhood, finding the top 100 venues within 1000 meter radius of each neighborhood.

# %%
def getNearByVenues(names, lats, lngs, radius = 1000):
  venue_list = []
  for lat,lng,name in zip(lats, lngs, names):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
      CLIENT_ID, 
      CLIENT_SECRET, 
      VERSION, 
      lat, 
      lng, 
      radius, 
      LIMIT)
    results = requests.get(url).json()["response"]["groups"][0]["items"]
    venue_list.append([(
        name,
        lat,
        lng,
        v["venue"]["name"],
        v["venue"]["location"]["lat"],
        v["venue"]["location"]["lng"],
        v["venue"]["categories"][0]["name"]) for v in results]
    )
  venue_df = pd.DataFrame([item for v in venue_list for item in v])
  venue_df.columns = [
                      "Neighborhood",
                      "Neighborhood Latitude",
                      "Neighborhood Longitude",
                      "Venue Name",
                      "Venue Latitude",
                      "Venue Longitude",
                      "Venue Category"
  ]
  return venue_df

Edison_venues = getNearByVenues(Edison["Neighborhood"], Edison["Latitude"], Edison["Longitude"], radius = 1000)

# %% [markdown]
# ###Dataframe: Edison_onehot---Using pd.get_dummies to change the venue categories into numerical values
#
# ###Dataframe: Edison_grouped---Using groupby to find for each neighborhood the mean value for each categories, the data frame is Edison

# %%
Edison_onehot = Edison_venues["Neighborhood"]
Edison_onehot = pd.concat([Edison_onehot, pd.get_dummies(Edison_venues["Venue Category"], prefix= "", prefix_sep="")], axis =1)
Edison_onehot.head()
Edison_grouped = Edison_onehot.groupby("Neighborhood").mean()
Edison_grouped.iloc[0].sort_values(ascending = False).head(10).index.values
# Out:
# array(['Furniture / Home Store', 'Park', 'Pizza Place', 'Sandwich Place',
#        'Hotel', 'Gym / Fitness Center', 'Pet Store', 'Salon / Barbershop',
#        'Chinese Restaurant', 'Rental Car Location'], dtype=object)

# %% [markdown]
# ### Dataframe: Edison_top_venues----In the mean time, by sort_values, find the top 10 popular venues for each neighborhood.

# %%
def get_top_venues(row, num_top):
  return row.sort_values(ascending = False).head(num_top).index.values
get_top_venues(Edison_grouped.iloc[0], 10)
# Out:
# array(['Furniture / Home Store', 'Park', 'Pizza Place', 'Sandwich Place',
#        'Hotel', 'Gym / Fitness Center', 'Pet Store', 'Salon / Barbershop',
#        'Chinese Restaurant', 'Rental Car Location'], dtype=object)

# %%
num_top = 10
ind = ["st", "nd", "rd"] # 1st, 2nd, 3rd
columns = ["Neighborhood", "Venue Label"]
for i in range(num_top):
  if i<=2:
    columns.append("{}{} Most Popular Venue".format(i+1, ind[i]))
  else:
    columns.append("{}th Most Popular Venue".format(i+1))
Edison_top_venues = pd.DataFrame(columns = columns)
Edison_top_venues["Neighborhood"] = Edison_grouped.index.values
for i in range(len(Edison_grouped)):
  row = Edison_grouped.iloc[i,:].T
  Edison_top_venues.iloc[i, 2:] = get_top_venues(row, 10)
Edison_top_venues
# Out:
#                 Neighborhood Venue Label  1st Most Popular Venue  \
# 0                 Bonhamtown         NaN  Furniture / Home Store
# 1           Camp Kilmer site         NaN                     Spa
# 2               Clara Barton         NaN           Deli / Bodega
# 3                  Greensand         NaN        Business Service
# 4                Haven Homes         NaN      Chinese Restaurant
# 5                    Lahiere         NaN      Chinese Restaurant
# 6               Lincoln Park         NaN      Chinese Restaurant
# 7                   Lindenau         NaN      Chinese Restaurant
# 8            Martins Landing         NaN      Mexican Restaurant
# 9                 Menlo Park         NaN       Indian Restaurant
# 10           Menlo Park Mall         NaN                   Train
# 11                 Metropark         NaN       Indian Restaurant
# 12  Middlesex County College         NaN             Pizza Place
# 13                 New Dover         NaN             Yoga Studio
# 14                New Durham         NaN                Pharmacy
# 15                     Nixon         NaN      Chinese Restaurant
# 16              North Edison         NaN          Gymnastics Gym
# 17                  Oak Tree         NaN                Pharmacy
# %%
KM = KMeans(n_clusters = 6, n_init = 12, random_state = 0)
KM.fit(Edison_grouped)
Edison_top_venues["Venue Label"] = KM.labels_

# %% [markdown]
# ### Dataframe: Edison_merge---- Edison_top_venues added with Venue Label, then merged into dataframe of Edison on "Neighborhood"

# %%
Edison_merge = Edison.merge(right = Edison_top_venues, on = "Neighborhood")
Edison_merge.sort_values("Venue Label", inplace= True)
Edison_merge
color_venue = ["red", "blue", "green", "yellow", "purple", "pink"]

for name, lat, lng, lbl in zip(Edison_merge["Neighborhood"], Edison_merge["Latitude"], Edison_merge["Longitude"], Edison_merge["Venue Label"]):
  color = color_venue[lbl]
  folium.CircleMarker(
      [lat, lng],
      popup = name,
      fill = True,
      color = color,
      fill_color = color,
      radius = 12,
      fill_opacity = 0.5
  ).add_to(Edison_map)

# %%
Edison_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Edison_merge
# Out:
#                 Neighborhood  \
# 30           Washington Park
# 7                   Lindenau
# 6               Lincoln Park
# 5                    Lahiere
# 27                   Stelton
# 3                  Greensand
# 1           Camp Kilmer site
# 4                Haven Homes
# 18             Oak Tree Road
# 28                 Valentine
# 19                   Phoenix
# 26               Silver Lake
# 25                Sand Hills
# 24             Raritan Manor
# 23            Raritan Center
# 21                   Potters
# 20                Piscataway
# 0                 Bonhamtown
# 16              North Edison
# 29          Vineyard Village
# 14                New Durham
# 12  Middlesex County College
# 10           Menlo Park Mall
# 2               Clara Barton
# 17                  Oak Tree
# 15                     Nixon
# 22                  Pumptown
# 11                 Metropark
# 9                 Menlo Park
# 13                 New Dover
# 8            Martins Landing
#
#                                                 Notes   Latitude  Longitude  \
# 30         Washington Park is to the east of Stelton.  40.513890 -74.398330
# 7   Lindenauis a neighborhood of the Stelton secti...  40.515000 -74.411110
# 6   For other places named Lincoln Park, New Jerse...  40.518890 -74.402500
# 5   Lahiere is a neighbohood in the Stelton sectio...  40.518890 -74.402500
# 27                    One the oldest parts of Edison.  40.514170 -74.403610
# 3   Site of the Kin-Buc Landfill, where Edmonds Cr...  40.491670 -74.387220
# 1   Abutting the Livingston Campus (Rutgers Univer...  40.520830 -74.413060
# 4                                                 NaN  40.509440 -74.406390
# 18  Shopping strip runs through Edison and neighbo...  40.522964 -74.411674
# 28  Valentine is adjacent to the Fords section of ...  40.530830 -74.325560
# 19  Located in the eastern part of the township, P...  40.529720 -74.341110
# 26  A small lake of same name borders the neighbor...  40.496209 -74.402813
# 25  Sand Hills is a neighborhood straddling Edison...  40.525000 -74.319440
# 24                                                NaN  40.536390 -74.336670
# 23  Sited on part if the former Raritan Arsenal,[4...  40.522500 -74.337780
# 21  In the northern part of the township Potters w...  40.593610 -74.361390
# 20  This is the oldest neighborhood in Edison. Alo...  40.501670 -74.395830
# 0   The neighborhood began as colonial village tha...  40.523330 -74.357780
# 16                                                NaN  40.600000 -74.377500
# 29  Adjacent to former Edison Assembly. Edward Ant...  40.524728 -74.375613
# 14                                                NaN  40.543610 -74.406110
# 26           Mobile Phone Shop     Miscellaneous Shop           Sandwich Place
# 25              Clothing Store           Liquor Store               Sports Bar
# 24              Sandwich Place             Restaurant                     Café
# 23              Sandwich Place              Cafeteria           Shipping Store
# 21  Construction & Landscaping            Golf Course           Cosmetics Shop
# 20                Optical Shop    Rental Car Location                      Pub
# 0           Salon / Barbershop     Chinese Restaurant      Rental Car Location
# 16           Food & Drink Shop                   Food     Fast Food Restaurant
# 29           Convenience Store         Shipping Store           Sandwich Place
# 14              Clothing Store         Sandwich Place       Chinese Restaurant
# 12                      Bakery      Convenience Store           Ice Cream Shop
# 10            Basketball Court           Intersection                      Bar
# 2            Mobile Phone Shop                   Café       Chinese Restaurant
# 17           Convenience Store     Salon / Barbershop             Optical Shop
# 15                  Donut Shop             Shoe Store             Burger Joint
# 22           Food & Drink Shop                   Food     Fast Food Restaurant
# 11          Chinese Restaurant       Asian Restaurant        Convenience Store
# 9                  Gas Station             Donut Shop  State / Provincial Park
# 13           Food & Drink Shop                   Food     Fast Food Restaurant
# 8                         Food   Fast Food Restaurant           Farmers Market

# %% [markdown]
# ###Edison_Chinatown

# %%
Edison_Chinatown = Edison_merge[Edison_merge["Venue Label"] == 0]
Edison_Chinatown
# Out:
#         Neighborhood                                              Notes  \
# 30   Washington Park         Washington Park is to the east of Stelton.
# 7           Lindenau  Lindenauis a neighborhood of the Stelton secti...
# 6       Lincoln Park  For other places named Lincoln Park, New Jerse...
# 5            Lahiere  Lahiere is a neighbohood in the Stelton sectio...
# 27           Stelton                    One the oldest parts of Edison.
# 3          Greensand  Site of the Kin-Buc Landfill, where Edmonds Cr...
# 1   Camp Kilmer site  Abutting the Livingston Campus (Rutgers Univer...
# 4        Haven Homes                                                NaN
# 18     Oak Tree Road  Shopping strip runs through Edison and neighbo...
#
#      Latitude  Longitude  Geo Label  Venue Label 1st Most Popular Venue  \
# 30  40.513890 -74.398330          1            0     Chinese Restaurant
# 7   40.515000 -74.411110          1            0     Chinese Restaurant
# 6   40.518890 -74.402500          1            0     Chinese Restaurant
# 5   40.518890 -74.402500          1            0     Chinese Restaurant
# 27  40.514170 -74.403610          1            0                 Bakery
# 3   40.491670 -74.387220          1            0       Business Service
# 1   40.520830 -74.413060          1            0                    Spa
# 4   40.509440 -74.406390          1            0     Chinese Restaurant
# 18  40.522964 -74.411674          1            0       Business Service
#
#    2nd Most Popular Venue 3rd Most Popular Venue 4th Most Popular Venue  \
# 30                 Bakery      Korean Restaurant           Dessert Shop
# 7                     Spa           Dessert Shop                 Bakery
# 6       Korean Restaurant       Asian Restaurant           Dessert Shop
# 5       Korean Restaurant       Asian Restaurant           Dessert Shop
# 27           Dessert Shop     Chinese Restaurant      Korean Restaurant
# 3                    Lake            Auto Garage         Rental Service
# 1       Korean Restaurant                 Bakery      Hotpot Restaurant
# 4       Korean Restaurant                 Bakery           Dessert Shop
# 18       Dentist's Office             Playground      Indian Restaurant
#
#    5th Most Popular Venue 6th Most Popular Venue      7th Most Popular Venue  \
# 30       Asian Restaurant        Bubble Tea Shop                    Pharmacy
# 7       Indian Restaurant        Bubble Tea Shop  Construction & Landscaping
# 6                  Bakery                   Bank        Fast Food Restaurant
# 5                  Bakery                   Bank        Fast Food Restaurant
# 27      Indian Restaurant         Sandwich Place                         Spa
# 3    Fast Food Restaurant            Yoga Studio              Farmers Market
# 1       Indian Restaurant       Dentist's Office               Deli / Bodega
# 4         Bubble Tea Shop            Wings Joint                         Spa
# 18          Deli / Bodega      Convenience Store                         Spa
#
#    8th Most Popular Venue 9th Most Popular Venue 10th Most Popular Venue
# 30         Farmers Market   Fast Food Restaurant          Sandwich Place
# 7       Korean Restaurant       Asian Restaurant                    Bank
# 6        Malay Restaurant                 Lawyer         Bubble Tea Shop
# 5        Malay Restaurant                 Lawyer         Bubble Tea Shop
# 27   Fast Food Restaurant                   Bank             Supermarket
# 3      Frozen Yogurt Shop    Fried Chicken Joint       Food & Drink Shop
# 1               BBQ Joint             Playground      Chinese Restaurant
# 4                Pharmacy             Hookah Bar             Supermarket
# 18                 Lawyer            Yoga Studio          Farmers Market

# %% [markdown]
# ###Visualization

# %%
Edison_Chinatown_map = folium.Map([40.514170, -74.403610], zoom_start= 18)
for name, lat, lng, lbl in zip(Edison_Chinatown["Neighborhood"], Edison_Chinatown["Latitude"], Edison_Chinatown["Longitude"], Edison_Chinatown["Venue Label"]):
  color = color_venue[lbl]
  folium.CircleMarker(
      [lat, lng],
      popup = name,
      fill = True,
      color = color,
      fill_color = color,
      radius = 12,
      fill_opacity = 0.3
  ).add_to(Edison_Chinatown_map)

# %%
Edison_Chinatown_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Edison_Chinatown_venues = Edison_venues[Edison_venues["Neighborhood"].isin(Edison_Chinatown["Neighborhood"])].reset_index(drop = True)
len(Edison_Chinatown_venues["Neighborhood"].unique())
Edison_Chinatown["Neighborhood"].unique()
Edison_Chinatown_venues["Venue Category"].value_counts()
# Out:
# Chinese Restaurant            37
# Bakery                        23
# Korean Restaurant             21
# Dessert Shop                  18
# Asian Restaurant              14
# Spa                           13
# Bubble Tea Shop               13
# Bank                          13
# Bagel Shop                    11
# Indian Restaurant             11
# Fast Food Restaurant          11
# Supermarket                   10
# Sandwich Place                 9
# Lawyer                         9
# Malay Restaurant               9
# Wings Joint                    9
# Playground                     8
# Pharmacy                       8
# BBQ Joint                      7
# Hotpot Restaurant              7
# Donut Shop                     7
# Sushi Restaurant               7
# Deli / Bodega                  6
# Pool Hall                      6
# Mongolian Restaurant           6
# Music Store                    6
# Mediterranean Restaurant       6
# Convenience Store              5
# Train                          4
# Hookah Bar                     4
# Coffee Shop                    4
# Miscellaneous Shop             4
# Italian Restaurant             3
# Frozen Yogurt Shop             3
# Dim Sum Restaurant             3
# Pizza Place                    3
# Video Store                    3
# Heliport                       3
# Lake                           3
# Construction & Landscaping     3
# Discount Store                 3
# Cosmetics Shop                 3
# Arts & Crafts Store            2
# Dentist's Office               2
# Business Service               2
# Gym / Fitness Center           2
# Steakhouse                     2
# Buffet                         2
# Farmers Market                 2
# Kids Store                     2
# Department Store               2
# Grocery Store                  1
# Train Station                  1
# Mobile Phone Shop              1
# Rental Car Location            1
# Mexican Restaurant             1
# Auto Dealership                1
# Rental Service                 1
# Breakfast Spot                 1
# Automotive Shop                1
# Auto Garage                    1
# Baseball Field                 1
# Gas Station                    1
# Video Game Store               1
# IT Services                    1
# Shopping Mall                  1
# High School                    1
# Motel                          1
# Ice Cream Shop                 1
# Shabu-Shabu Restaurant         1
# Diner                          1
# Furniture / Home Store         1
# Name: Venue Category, dtype: int64

# %% [markdown]
# [‘red’, ‘blue’, ‘green’, ‘purple’, ‘orange’, ‘darkred’,
# ’lightred’, ‘beige’, ‘darkblue’, ‘darkgreen’, ‘cadetblue’, ‘darkpurple’, ‘white’, ‘pink’, ‘lightblue’, ‘lightgreen’, ‘gray’, ‘black’, ‘lightgray’]

# %%
categories_restaurant = ["Chinese Restaurant", "Korean Restaurant", "Malay Restaurant", "Mongolian Restaurant", "Indian Restaurant"]
colors_restaurant = ["red", "darkblue", "purple", "lightgreen", "darkgreen"]
categories_dessert = ["Bakery", "Dessert Shop", "Bubble Tea Shop", "Frozon Yogurt Shop"]
colors_dessert = ["orange", "pink", "beige", "lightblue" ]
Edison_Chinatown_asian_restaurant = Edison_Chinatown_venues[Edison_Chinatown_venues["Venue Category"].isin(categories_restaurant)]
Edison_Chinatown_dessert = Edison_Chinatown_venues[Edison_Chinatown_venues["Venue Category"].isin(categories_dessert)]
Edison_Chinatown_asian_restaurant.sort_values("Venue Category")
categories_supermarket = ["Supermarket", "Farmers Market"]
Edison_Chinatown_supermarket = Edison_Chinatown_venues[Edison_Chinatown_venues["Venue Category"].isin(categories_supermarket)]
colors_supermarket = ["blue", "green"]

# %% [markdown]
# ###More detailed categories focusing on Chinatown and restaurant/dessert shop/supermarket

# %%
# !pip install fontawesome

# %%
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
display(HTML('<link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>'))

def add_marker_to_map(df, categories, colors, icon,  map = Edison_Chinatown_map):
  for name, lat, lng, cat in zip(df["Venue Name"], df["Venue Latitude"], df["Venue Longitude"], df["Venue Category"]):
    for i in range(len(categories)):
      if cat == categories[i]:
        color = colors[i]
    folium.Marker(
      [lat, lng],
      popup = name +", " +cat,
      icon = folium.Icon(color = color, icon_color = "white", icon= icon, prefix ="fa")
    ).add_to(map)
colors = []
categories = []
df = Edison_Chinatown_asian_restaurant
categories = categories_restaurant
colors = colors_restaurant
icon = "cutlery"
add_marker_to_map(df, categories, colors, icon,  map = Edison_Chinatown_map)

colors = []
categories = []
df = Edison_Chinatown_dessert
categories = categories_dessert
colors = colors_dessert
icon = "coffee"
add_marker_to_map(df, categories, colors, icon,  map = Edison_Chinatown_map)

colors = []
categories = []
df = Edison_Chinatown_supermarket
categories = categories_supermarket
colors = colors_supermarket
icon = "shopping-cart"
add_marker_to_map(df, categories, colors, icon,  map = Edison_Chinatown_map)
# Out:
# <link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>

# %%
display(HTML('<link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>'))
Edison_Chinatown_map
# Out:
# <link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
